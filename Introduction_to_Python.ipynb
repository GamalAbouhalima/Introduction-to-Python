# %% [markdown]
# <a href="https://colab.research.google.com/github/GamalAbouhalima/GamalAbouhalima/blob/main/Introduction_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction to python

# %%
print("Hello","Gamal")
# Out:
# Hello Gamal

# %%
name=input("What is Your Name? ")
print ("Hello",name)
# Out:
# What is Your Name? Gamal
# Hello Gamal

# %%
num1=int (input("Enter number One: "))
num2=int (input("Enter number Two: "))
print("Sum = ",num1+num2)
# Out:
# Enter number One: 10
# Enter number Two: 12
# Sum =  22

# %%
x="Gamal"
x=25
print(x)
# Out:
# 25

# %% [markdown]
# #Type Conversion

# %%
x=2
x=float(x)
print(x)
# Out:
# 2.0

# %%
x=3.9
x=int(x)
print(x)
# Out:
# 3

# %%
b=True
b=int(b)
print(b)
# Out:
# 1

# %%
c=True
c=float(c)
print(c)
# Out:
# 1.0

# %%
d=9
d=bool(d)
print(d)
# Out:
# True

# %%
d=0
d=bool(d)
print(d)
# Out:
# False

# %%
d=-9
d=bool(d)
print(d)
# Out:
# True

# %%
x=8
x=str(x)
print(x)
# Out:
# 8

# %%
y=x+"5"
y
# Out:
# '85'

# %% [markdown]
# #Convert from STring to Boolean

# %%
x="Hello"
x=bool(x)
print(x)
# Out:
# True

# %%
x="false"
x=bool(x)
print(x)
# Out:
# True

# %% [markdown]
# Convert from String to int or float

# %%
x="5"
x=int(x)
print(x+5)
# Out:
# 10

# %%
x="5"
x=float(x)
print(x+5)
# Out:
# 10.0

# %%
x="5.5"
x=int(x)
print(x+5)
#you must convert to floate firstly and convert to int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-047e8c530ebd> in <cell line: 2>()
#       1 x="5.5"
# ----> 2 x=int(x)
#       3 print(x+5)
#
# ValueError: invalid literal for int() with base 10: '5.5'

# %% [markdown]
# #if condition

# %%
x=int(input("Enter a number: "))
if x > 0:
  print("x is positive ")
elif x == 0:
  print("x is zero")
else:
  print("x is negative")
# Out:
# Enter a number: 0
# x is zero

# %%
order=50
member=True
if not (order>100 and member==True):
  print("You have discount 10%")
elif(order>100 and member==False):
  print("You have discount 5%")
else:
  print("No discount")
# Out:
# You have discount 10%

# %%
num=int(input("Enter a number: "))
if num%2==0:
  print("Even")
else:
  print("Odd")
# Out:
# Enter a number: 0
# Even
